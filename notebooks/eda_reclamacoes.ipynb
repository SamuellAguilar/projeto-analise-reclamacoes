# %% [markdown]
# # Análise de Reclamações de Consumidores no Brasil
#
# Projeto desenvolvido no curso de Análise de Dados da EBAC,
# em parceria com a Semantix, utilizando dados públicos do
# Consumidor.gov.br.

# %% [markdown]
# ## Descrição do Problema
#
# Com o aumento do consumo de produtos e serviços, principalmente
# em ambientes digitais, o número de reclamações registradas por
# consumidores também cresce de forma significativa. Essas reclamações
# representam problemas relacionados a atendimento, cobrança,
# entrega e qualidade dos serviços prestados pelas empresas.
#
# Analisar esses dados de forma estruturada é fundamental para
# identificar padrões, empresas mais reclamadas e os principais
# tipos de problemas enfrentados pelos consumidores. A análise de
# dados permite transformar registros individuais em informações
# relevantes, auxiliando na tomada de decisões e na melhoria dos
# processos de atendimento ao consumidor.

# %% [markdown]
# ### Coleta de Dados

# %%
import pandas as pd

# %%
import os

os.listdir('/content')
# Out:
# ['.config',
#  'basecompleta2025-12.csv',
#  'basecompleta2025-10.csv',
#  'reclamacoes_tratadas.csv',
#  'basecompleta2025-11.csv',
#  'sample_data']

# %%
arquivos = [
    '/content/basecompleta2025-10.csv',
    '/content/basecompleta2025-11.csv',
    '/content/basecompleta2025-12.csv'
]

df = pd.concat([pd.read_csv(arq, on_bad_lines='warn') for arq in arquivos])

df.head()
# Out:
# A saída de streaming foi truncada nas últimas 5000 linhas.
# Skipping line 306515: expected 2 fields, saw 5
# Skipping line 306518: expected 2 fields, saw 4
# Skipping line 306520: expected 2 fields, saw 5
# Skipping line 306522: expected 2 fields, saw 3
# Skipping line 306523: expected 2 fields, saw 3
# Skipping line 306524: expected 2 fields, saw 3
# Skipping line 306530: expected 2 fields, saw 7
# Skipping line 306532: expected 2 fields, saw 3
# Skipping line 306533: expected 2 fields, saw 8
# Skipping line 306535: expected 2 fields, saw 3
# Skipping line 306537: expected 2 fields, saw 3
# Skipping line 306539: expected 2 fields, saw 3
# Skipping line 306541: expected 2 fields, saw 3
# Skipping line 306543: expected 2 fields, saw 4
# Skipping line 306546: expected 2 fields, saw 3
# Skipping line 306547: expected 2 fields, saw 9
# Skipping line 306549: expected 2 fields, saw 5
# Skipping line 306550: expected 2 fields, saw 3
# Skipping line 306553: expected 2 fields, saw 3
# Skipping line 306554: expected 2 fields, saw 4
# Skipping line 306555: expected 2 fields, saw 3
# Skipping line 306556: expected 2 fields, saw 5
# Skipping line 306558: expected 2 fields, saw 3
# Skipping line 306559: expected 2 fields, saw 7
# Skipping line 306561: expected 2 fields, saw 3
# Skipping line 306562: expected 2 fields, saw 4
# Skipping line 306563: expected 2 fields, saw 5
# Skipping line 306566: expected 2 fields, saw 5
# Skipping line 306569: expected 2 fields, saw 3
# Skipping line 306574: expected 2 fields, saw 3
# Skipping line 306578: expected 2 fields, saw 3
# Skipping line 306581: expected 2 fields, saw 3
# Skipping line 306582: expected 2 fields, saw 3
# Skipping line 306583: expected 2 fields, saw 3
# Skipping line 306584: expected 2 fields, saw 3
# Skipping line 306587: expected 2 fields, saw 4
# Skipping line 306588: expected 2 fields, saw 5
# Skipping line 306593: expected 2 fields, saw 5
# Skipping line 306594: expected 2 fields, saw 6
# Skipping line 306595: expected 2 fields, saw 8
# Skipping line 306597: expected 2 fields, saw 3
# Skipping line 306599: expected 2 fields, saw 4
# Skipping line 306600: expected 2 fields, saw 3
# Skipping line 306604: expected 2 fields, saw 3
# Skipping line 306605: expected 2 fields, saw 3
# Skipping line 306607: expected 2 fields, saw 5
# Skipping line 306608: expected 2 fields, saw 8
# Skipping line 306609: expected 2 fields, saw 3
# Skipping line 306611: expected 2 fields, saw 3
# Skipping line 306613: expected 2 fields, saw 4
# Skipping line 306615: expected 2 fields, saw 5
# Skipping line 306616: expected 2 fields, saw 3
# Skipping line 306619: expected 2 fields, saw 5
# Skipping line 306621: expected 2 fields, saw 6
# Skipping line 306622: expected 2 fields, saw 5
# Skipping line 306625: expected 2 fields, saw 5
# Skipping line 306627: expected 2 fields, saw 4
# Skipping line 306634: expected 2 fields, saw 3
# Skipping line 306637: expected 2 fields, saw 5
# Skipping line 306638: expected 2 fields, saw 5
# Skipping line 306639: expected 2 fields, saw 5
# Skipping line 306641: expected 2 fields, saw 3
# Skipping line 306643: expected 2 fields, saw 4
# Skipping line 306644: expected 2 fields, saw 4
# Skipping line 306646: expected 2 fields, saw 3
# Skipping line 306649: expected 2 fields, saw 9
# Skipping line 306651: expected 2 fields, saw 5
# Skipping line 306656: expected 2 fields, saw 3
# Skipping line 306657: expected 2 fields, saw 8
# Skipping line 306663: expected 2 fields, saw 4
# Skipping line 306664: expected 2 fields, saw 5
# Skipping line 306667: expected 2 fields, saw 5
# Skipping line 306669: expected 2 fields, saw 4
# Skipping line 306671: expected 2 fields, saw 3
# Skipping line 306673: expected 2 fields, saw 7
# Skipping line 306675: expected 2 fields, saw 4
# Skipping line 306678: expected 2 fields, saw 3
# Skipping line 306680: expected 2 fields, saw 5
# Skipping line 306683: expected 2 fields, saw 3
# Skipping line 306684: expected 2 fields, saw 3
# Skipping line 306685: expected 2 fields, saw 8
# Skipping line 306689: expected 2 fields, saw 3
# Skipping line 306690: expected 2 fields, saw 3
# Skipping line 306692: expected 2 fields, saw 3
# Skipping line 306693: expected 2 fields, saw 4
# Skipping line 306694: expected 2 fields, saw 5
# Skipping line 306696: expected 2 fields, saw 7
# Skipping line 306697: expected 2 fields, saw 6
# Skipping line 306700: expected 2 fields, saw 4
# Skipping line 306706: expected 2 fields, saw 4
# Skipping line 306707: expected 2 fields, saw 4
# Skipping line 306710: expected 2 fields, saw 3
# Skipping line 306711: expected 2 fields, saw 3
# Skipping line 306712: expected 2 fields, saw 5
# Skipping line 306714: expected 2 fields, saw 4
# Skipping line 306715: expected 2 fields, saw 3
# Skipping line 306718: expected 2 fields, saw 5
# Skipping line 306720: expected 2 fields, saw 5
# Skipping line 306722: expected 2 fields, saw 3
# Skipping line 306723: expected 2 fields, saw 4
# Skipping line 306726: expected 2 fields, saw 5
# Skipping line 306729: expected 2 fields, saw 3
# Skipping line 306730: expected 2 fields, saw 3
# Skipping line 306731: expected 2 fields, saw 5
# Skipping line 306732: expected 2 fields, saw 3
# Skipping line 306734: expected 2 fields, saw 5
# Skipping line 306736: expected 2 fields, saw 3
# Skipping line 306739: expected 2 fields, saw 5
# Skipping line 306744: expected 2 fields, saw 4
# Skipping line 306745: expected 2 fields, saw 5
# Skipping line 306747: expected 2 fields, saw 5
# Skipping line 306748: expected 2 fields, saw 3
# Skipping line 306749: expected 2 fields, saw 3
# Skipping line 306751: expected 2 fields, saw 3
# Skipping line 306752: expected 2 fields, saw 3
# Skipping line 306756: expected 2 fields, saw 5
# Skipping line 306760: expected 2 fields, saw 3
# Skipping line 306761: expected 2 fields, saw 5
# Skipping line 306762: expected 2 fields, saw 5
# Skipping line 306767: expected 2 fields, saw 3
# Skipping line 306770: expected 2 fields, saw 4
# Skipping line 306772: expected 2 fields, saw 3
# Skipping line 306773: expected 2 fields, saw 3
# Skipping line 306774: expected 2 fields, saw 5
# Skipping line 306781: expected 2 fields, saw 3
# Skipping line 306783: expected 2 fields, saw 4
# Skipping line 306786: expected 2 fields, saw 4
# Skipping line 306787: expected 2 fields, saw 8
# Skipping line 306788: expected 2 fields, saw 5
# Skipping line 306789: expected 2 fields, saw 3
# Skipping line 306794: expected 2 fields, saw 5
# Skipping line 306798: expected 2 fields, saw 4
# Skipping line 306802: expected 2 fields, saw 9
# Skipping line 306803: expected 2 fields, saw 3
# Skipping line 306804: expected 2 fields, saw 3
# Skipping line 306807: expected 2 fields, saw 3
# Skipping line 306808: expected 2 fields, saw 5
# Skipping line 306809: expected 2 fields, saw 5
# Skipping line 306810: expected 2 fields, saw 3
# Skipping line 306811: expected 2 fields, saw 3
# Skipping line 306812: expected 2 fields, saw 5
# Skipping line 306813: expected 2 fields, saw 5
# Skipping line 306814: expected 2 fields, saw 4
# Skipping line 306820: expected 2 fields, saw 4
# Skipping line 306821: expected 2 fields, saw 4
# Skipping line 306822: expected 2 fields, saw 3
# Skipping line 306830: expected 2 fields, saw 3
# Skipping line 306831: expected 2 fields, saw 4
# Skipping line 306832: expected 2 fields, saw 5
# Skipping line 306833: expected 2 fields, saw 3
# Skipping line 306835: expected 2 fields, saw 4
# Skipping line 306837: expected 2 fields, saw 5
# Skipping line 306838: expected 2 fields, saw 3
# Skipping line 306842: expected 2 fields, saw 3
# Skipping line 306844: expected 2 fields, saw 4
# Skipping line 306845: expected 2 fields, saw 3
# Skipping line 306847: expected 2 fields, saw 6
# Skipping line 306849: expected 2 fields, saw 5
# Skipping line 306853: expected 2 fields, saw 4
# Skipping line 306856: expected 2 fields, saw 3
# Skipping line 306859: expected 2 fields, saw 3
# Skipping line 306860: expected 2 fields, saw 3
# Skipping line 306861: expected 2 fields, saw 5
# Skipping line 306864: expected 2 fields, saw 3
# Skipping line 306865: expected 2 fields, saw 7
# Skipping line 306866: expected 2 fields, saw 3
# Skipping line 306868: expected 2 fields, saw 4
# Skipping line 306869: expected 2 fields, saw 3
# Skipping line 306872: expected 2 fields, saw 3
# Skipping line 306873: expected 2 fields, saw 8
# Skipping line 306876: expected 2 fields, saw 5
# Skipping line 306879: expected 2 fields, saw 5
# Skipping line 306880: expected 2 fields, saw 3
# Skipping line 306884: expected 2 fields, saw 3
# Skipping line 306885: expected 2 fields, saw 3
# Skipping line 306886: expected 2 fields, saw 3
# Skipping line 306887: expected 2 fields, saw 3
# Skipping line 306888: expected 2 fields, saw 3
# Skipping line 306889: expected 2 fields, saw 5
# Skipping line 306892: expected 2 fields, saw 3
# Skipping line 306893: expected 2 fields, saw 3
# Skipping line 306897: expected 2 fields, saw 3
# Skipping line 306898: expected 2 fields, saw 3
# Skipping line 306899: expected 2 fields, saw 3
# Skipping line 306907: expected 2 fields, saw 7
# Skipping line 306908: expected 2 fields, saw 5
# Skipping line 306911: expected 2 fields, saw 5
# Skipping line 306912: expected 2 fields, saw 3
# Skipping line 306914: expected 2 fields, saw 3
# Skipping line 306915: expected 2 fields, saw 3
# Skipping line 306916: expected 2 fields, saw 3
# Skipping line 306917: expected 2 fields, saw 3
# Skipping line 306919: expected 2 fields, saw 8
# Skipping line 306920: expected 2 fields, saw 3
# Skipping line 306921: expected 2 fields, saw 6
# Skipping line 306923: expected 2 fields, saw 5
# Skipping line 306927: expected 2 fields, saw 3
# Skipping line 306929: expected 2 fields, saw 5
# Skipping line 306931: expected 2 fields, saw 5
# Skipping line 306935: expected 2 fields, saw 5
# Skipping line 306936: expected 2 fields, saw 6
# Skipping line 306940: expected 2 fields, saw 3
# Skipping line 306943: expected 2 fields, saw 4
# Skipping line 306945: expected 2 fields, saw 6
# Skipping line 306948: expected 2 fields, saw 5
# Skipping line 306949: expected 2 fields, saw 6
# Skipping line 306950: expected 2 fields, saw 3
# Skipping line 306951: expected 2 fields, saw 6
# Skipping line 306954: expected 2 fields, saw 3
# Skipping line 306955: expected 2 fields, saw 3
# Skipping line 306956: expected 2 fields, saw 4
# Skipping line 306963: expected 2 fields, saw 5
# Skipping line 306964: expected 2 fields, saw 3
# Skipping line 306965: expected 2 fields, saw 3
# Skipping line 306966: expected 2 fields, saw 3
# Skipping line 306970: expected 2 fields, saw 5
# Skipping line 306971: expected 2 fields, saw 9
# Skipping line 306983: expected 2 fields, saw 3
# Skipping line 306985: expected 2 fields, saw 5
# Skipping line 306987: expected 2 fields, saw 9
# Skipping line 306988: expected 2 fields, saw 3
# Skipping line 306989: expected 2 fields, saw 3
# Skipping line 306990: expected 2 fields, saw 4
# Skipping line 306992: expected 2 fields, saw 3
# Skipping line 306994: expected 2 fields, saw 8
# Skipping line 306997: expected 2 fields, saw 3
# Skipping line 306999: expected 2 fields, saw 5
# Skipping line 307001: expected 2 fields, saw 3
# Skipping line 307004: expected 2 fields, saw 3
# Skipping line 307005: expected 2 fields, saw 3
# Skipping line 307006: expected 2 fields, saw 3
# Skipping line 307009: expected 2 fields, saw 3
# Skipping line 307010: expected 2 fields, saw 3
# Skipping line 307011: expected 2 fields, saw 3
# Skipping line 307016: expected 2 fields, saw 4
# Skipping line 307018: expected 2 fields, saw 8
# Skipping line 307023: expected 2 fields, saw 3
# Skipping line 307027: expected 2 fields, saw 3
# Skipping line 307028: expected 2 fields, saw 3
# Skipping line 307029: expected 2 fields, saw 3
# Skipping line 307031: expected 2 fields, saw 3
# Skipping line 307032: expected 2 fields, saw 3
# Skipping line 307034: expected 2 fields, saw 3
# Skipping line 307035: expected 2 fields, saw 5
# Skipping line 307036: expected 2 fields, saw 3
# Skipping line 307038: expected 2 fields, saw 5
# Skipping line 307039: expected 2 fields, saw 3
# Skipping line 307041: expected 2 fields, saw 5
# Skipping line 307043: expected 2 fields, saw 5
# Skipping line 307046: expected 2 fields, saw 4
# Skipping line 307048: expected 2 fields, saw 5
# Skipping line 307050: expected 2 fields, saw 4
# Skipping line 307052: expected 2 fields, saw 3
# Skipping line 307056: expected 2 fields, saw 3
# Skipping line 307057: expected 2 fields, saw 3
# Skipping line 307058: expected 2 fields, saw 4
# Skipping line 307060: expected 2 fields, saw 9
# Skipping line 307061: expected 2 fields, saw 4
# Skipping line 307062: expected 2 fields, saw 3
# Skipping line 307064: expected 2 fields, saw 5
# Skipping line 307066: expected 2 fields, saw 4
# Skipping line 307069: expected 2 fields, saw 3
# Skipping line 307071: expected 2 fields, saw 3
# Skipping line 307072: expected 2 fields, saw 3
# Skipping line 307073: expected 2 fields, saw 3
# Skipping line 307075: expected 2 fields, saw 3
# Skipping line 307076: expected 2 fields, saw 3
# Skipping line 307080: expected 2 fields, saw 3
# Skipping line 307081: expected 2 fields, saw 3
# Skipping line 307083: expected 2 fields, saw 5
# Skipping line 307084: expected 2 fields, saw 3
# Skipping line 307086: expected 2 fields, saw 3
# Skipping line 307089: expected 2 fields, saw 4
# Skipping line 307091: expected 2 fields, saw 6
# Skipping line 307093: expected 2 fields, saw 7
# Skipping line 307094: expected 2 fields, saw 3
# Skipping line 307097: expected 2 fields, saw 9
# Skipping line 307100: expected 2 fields, saw 4
# Skipping line 307107: expected 2 fields, saw 4
# Skipping line 307109: expected 2 fields, saw 3
# Skipping line 307111: expected 2 fields, saw 5
# Skipping line 307113: expected 2 fields, saw 3
# Skipping line 307114: expected 2 fields, saw 3
# Skipping line 307118: expected 2 fields, saw 3
# Skipping line 307122: expected 2 fields, saw 3
# Skipping line 307124: expected 2 fields, saw 3
# Skipping line 307126: expected 2 fields, saw 4
# Skipping line 307131: expected 2 fields, saw 3
# Skipping line 307134: expected 2 fields, saw 3
# Skipping line 307136: expected 2 fields, saw 5
# Skipping line 307137: expected 2 fields, saw 3
# Skipping line 307138: expected 2 fields, saw 3
# Skipping line 307140: expected 2 fields, saw 4
# Skipping line 307142: expected 2 fields, saw 9
# Skipping line 307143: expected 2 fields, saw 5
# Skipping line 307145: expected 2 fields, saw 3
# Skipping line 307147: expected 2 fields, saw 3
# Skipping line 307150: expected 2 fields, saw 5
# Skipping line 307151: expected 2 fields, saw 5
# Skipping line 307153: expected 2 fields, saw 3
# Skipping line 307162: expected 2 fields, saw 8
# Skipping line 307164: expected 2 fields, saw 7
# Skipping line 307167: expected 2 fields, saw 3
# Skipping line 307170: expected 2 fields, saw 3
# Skipping line 307178: expected 2 fields, saw 5
# Skipping line 307181: expected 2 fields, saw 3
# Skipping line 307184: expected 2 fields, saw 6
# Skipping line 307186: expected 2 fields, saw 3
# Skipping line 307188: expected 2 fields, saw 5
# Skipping line 307191: expected 2 fields, saw 7
# Skipping line 307195: expected 2 fields, saw 3
# Skipping line 307196: expected 2 fields, saw 5
# Skipping line 307199: expected 2 fields, saw 4
# Skipping line 307201: expected 2 fields, saw 4
# Skipping line 307208: expected 2 fields, saw 3
# Skipping line 307209: expected 2 fields, saw 3
# Skipping line 307211: expected 2 fields, saw 5
# Skipping line 307213: expected 2 fields, saw 3
# Skipping line 307214: expected 2 fields, saw 3
# Skipping line 307215: expected 2 fields, saw 3
# Skipping line 307223: expected 2 fields, saw 3
# Skipping line 307225: expected 2 fields, saw 5
# Skipping line 307226: expected 2 fields, saw 3
# Skipping line 307229: expected 2 fields, saw 5
# Skipping line 307232: expected 2 fields, saw 5
# Skipping line 307233: expected 2 fields, saw 4
# Skipping line 307234: expected 2 fields, saw 5
# Skipping line 307238: expected 2 fields, saw 3
# Skipping line 307239: expected 2 fields, saw 3
# Skipping line 307240: expected 2 fields, saw 3
# Skipping line 307245: expected 2 fields, saw 5
# Skipping line 307248: expected 2 fields, saw 3
# Skipping line 307250: expected 2 fields, saw 5
# Skipping line 307251: expected 2 fields, saw 9
# Skipping line 307252: expected 2 fields, saw 3
# Skipping line 307256: expected 2 fields, saw 5
# Skipping line 307258: expected 2 fields, saw 3
# Skipping line 307259: expected 2 fields, saw 5
# Skipping line 307263: expected 2 fields, saw 3
# Skipping line 307265: expected 2 fields, saw 3
# Skipping line 307266: expected 2 fields, saw 3
# Skipping line 307270: expected 2 fields, saw 5
# Skipping line 307272: expected 2 fields, saw 5
# Skipping line 307274: expected 2 fields, saw 4
# Skipping line 307275: expected 2 fields, saw 4
# Skipping line 307276: expected 2 fields, saw 4
# Skipping line 307282: expected 2 fields, saw 4
# Skipping line 307285: expected 2 fields, saw 3
# Skipping line 307292: expected 2 fields, saw 4
# Skipping line 307294: expected 2 fields, saw 5
# Skipping line 307297: expected 2 fields, saw 3
# Skipping line 307306: expected 2 fields, saw 7
# Skipping line 307309: expected 2 fields, saw 7
# Skipping line 307314: expected 2 fields, saw 3
# Skipping line 307318: expected 2 fields, saw 3
# Skipping line 307322: expected 2 fields, saw 5
# Skipping line 307323: expected 2 fields, saw 3
# Skipping line 307327: expected 2 fields, saw 5
# Skipping line 307333: expected 2 fields, saw 3
# Skipping line 307337: expected 2 fields, saw 4
# Skipping line 307338: expected 2 fields, saw 5
# Skipping line 307341: expected 2 fields, saw 3
# Skipping line 307345: expected 2 fields, saw 9
# Skipping line 307348: expected 2 fields, saw 3
# Skipping line 307352: expected 2 fields, saw 4
# Skipping line 307359: expected 2 fields, saw 3
# Skipping line 307363: expected 2 fields, saw 8
# Skipping line 307366: expected 2 fields, saw 3
# Skipping line 307368: expected 2 fields, saw 3
# Skipping line 307369: expected 2 fields, saw 3
# Skipping line 307370: expected 2 fields, saw 3
# Skipping line 307372: expected 2 fields, saw 3
# Skipping line 307374: expected 2 fields, saw 5
# Skipping line 307377: expected 2 fields, saw 3
# Skipping line 307378: expected 2 fields, saw 4
# Skipping line 307380: expected 2 fields, saw 3
# Skipping line 307381: expected 2 fields, saw 3
# Skipping line 307384: expected 2 fields, saw 4
# Skipping line 307385: expected 2 fields, saw 3
# Skipping line 307388: expected 2 fields, saw 4
# Skipping line 307390: expected 2 fields, saw 7
# Skipping line 307392: expected 2 fields, saw 5
# Skipping line 307393: expected 2 fields, saw 7
# Skipping line 307395: expected 2 fields, saw 3
# Skipping line 307397: expected 2 fields, saw 3
# Skipping line 307398: expected 2 fields, saw 6
# Skipping line 307400: expected 2 fields, saw 3
# Skipping line 307403: expected 2 fields, saw 4
# Skipping line 307406: expected 2 fields, saw 4
# Skipping line 307407: expected 2 fields, saw 5
# Skipping line 307408: expected 2 fields, saw 3
# Skipping line 307409: expected 2 fields, saw 5
# Skipping line 307410: expected 2 fields, saw 3
# Skipping line 307411: expected 2 fields, saw 3
# Skipping line 307413: expected 2 fields, saw 3
# Skipping line 307415: expected 2 fields, saw 8
# Skipping line 307416: expected 2 fields, saw 4
# Skipping line 307417: expected 2 fields, saw 3
# Skipping line 307418: expected 2 fields, saw 3
# Skipping line 307419: expected 2 fields, saw 5
# Skipping line 307420: expected 2 fields, saw 3
# Skipping line 307423: expected 2 fields, saw 3
# Skipping line 307424: expected 2 fields, saw 5
# Skipping line 307425: expected 2 fields, saw 3
# Skipping line 307429: expected 2 fields, saw 6
# Skipping line 307431: expected 2 fields, saw 7
# Skipping line 307432: expected 2 fields, saw 4
# Skipping line 307433: expected 2 fields, saw 7
# Skipping line 307434: expected 2 fields, saw 5
# Skipping line 307435: expected 2 fields, saw 3
# Skipping line 307436: expected 2 fields, saw 8
# Skipping line 307440: expected 2 fields, saw 6
# Skipping line 307443: expected 2 fields, saw 3
# Skipping line 307447: expected 2 fields, saw 3
# Skipping line 307449: expected 2 fields, saw 3
# Skipping line 307450: expected 2 fields, saw 3
# Skipping line 307451: expected 2 fields, saw 4
# Skipping line 307452: expected 2 fields, saw 3
# Skipping line 307455: expected 2 fields, saw 3
# Skipping line 307456: expected 2 fields, saw 3
# Skipping line 307457: expected 2 fields, saw 8
# Skipping line 307460: expected 2 fields, saw 5
# Skipping line 307462: expected 2 fields, saw 5
# Skipping line 307463: expected 2 fields, saw 3
# Skipping line 307464: expected 2 fields, saw 5
# Skipping line 307467: expected 2 fields, saw 6
# Skipping line 307469: expected 2 fields, saw 5
# Skipping line 307470: expected 2 fields, saw 3
# Skipping line 307474: expected 2 fields, saw 3
# Skipping line 307484: expected 2 fields, saw 3
# Skipping line 307486: expected 2 fields, saw 5
# Skipping line 307490: expected 2 fields, saw 3
# Skipping line 307491: expected 2 fields, saw 3
# Skipping line 307493: expected 2 fields, saw 5
# Skipping line 307494: expected 2 fields, saw 4
# Skipping line 307495: expected 2 fields, saw 5
# Skipping line 307498: expected 2 fields, saw 5
# Skipping line 307500: expected 2 fields, saw 3
# Skipping line 307502: expected 2 fields, saw 5
# Skipping line 307505: expected 2 fields, saw 5
# Skipping line 307506: expected 2 fields, saw 4
# Skipping line 307508: expected 2 fields, saw 5
# Skipping line 307509: expected 2 fields, saw 4
# Skipping line 307510: expected 2 fields, saw 8
# Skipping line 307511: expected 2 fields, saw 3
# Skipping line 307512: expected 2 fields, saw 6
# Skipping line 307513: expected 2 fields, saw 4
# Skipping line 307514: expected 2 fields, saw 3
# Skipping line 307516: expected 2 fields, saw 5
# Skipping line 307517: expected 2 fields, saw 3
# Skipping line 307518: expected 2 fields, saw 7
# Skipping line 307520: expected 2 fields, saw 4
# Skipping line 307522: expected 2 fields, saw 5
# Skipping line 307531: expected 2 fields, saw 5
# Skipping line 307533: expected 2 fields, saw 4
# Skipping line 307535: expected 2 fields, saw 5
# Skipping line 307536: expected 2 fields, saw 5
# Skipping line 307542: expected 2 fields, saw 3
# Skipping line 307545: expected 2 fields, saw 5
# Skipping line 307547: expected 2 fields, saw 5
# Skipping line 307552: expected 2 fields, saw 5
# Skipping line 307558: expected 2 fields, saw 3
# Skipping line 307562: expected 2 fields, saw 3
# Skipping line 307569: expected 2 fields, saw 4
# Skipping line 307570: expected 2 fields, saw 3
# Skipping line 307574: expected 2 fields, saw 5
# Skipping line 307576: expected 2 fields, saw 4
# Skipping line 307577: expected 2 fields, saw 3
# Skipping line 307579: expected 2 fields, saw 3
# Skipping line 307583: expected 2 fields, saw 4
# Skipping line 307585: expected 2 fields, saw 3
# Skipping line 307586: expected 2 fields, saw 3
# Skipping line 307588: expected 2 fields, saw 3
# Skipping line 307589: expected 2 fields, saw 5
# Skipping line 307590: expected 2 fields, saw 5
# Skipping line 307591: expected 2 fields, saw 8
# Skipping line 307592: expected 2 fields, saw 5
# Skipping line 307594: expected 2 fields, saw 3
# Skipping line 307596: expected 2 fields, saw 3
# Skipping line 307599: expected 2 fields, saw 5
# Skipping line 307603: expected 2 fields, saw 5
# Skipping line 307604: expected 2 fields, saw 3
# Skipping line 307608: expected 2 fields, saw 3
# Skipping line 307609: expected 2 fields, saw 3
# Skipping line 307618: expected 2 fields, saw 4
# Skipping line 307624: expected 2 fields, saw 5
# Skipping line 307628: expected 2 fields, saw 5
# Skipping line 307629: expected 2 fields, saw 3
# Skipping line 307630: expected 2 fields, saw 3
# Skipping line 307631: expected 2 fields, saw 5
# Skipping line 307634: expected 2 fields, saw 3
# Skipping line 307638: expected 2 fields, saw 3
# Skipping line 307639: expected 2 fields, saw 5
# Skipping line 307640: expected 2 fields, saw 3
# Skipping line 307641: expected 2 fields, saw 3
# Skipping line 307643: expected 2 fields, saw 4
# Skipping line 307645: expected 2 fields, saw 5
# Skipping line 307646: expected 2 fields, saw 3
# Skipping line 307650: expected 2 fields, saw 3
# Skipping line 307651: expected 2 fields, saw 5
# Skipping line 307652: expected 2 fields, saw 3
# Skipping line 307653: expected 2 fields, saw 5
# Skipping line 307656: expected 2 fields, saw 5
# Skipping line 307658: expected 2 fields, saw 4
# Skipping line 307660: expected 2 fields, saw 7
# Skipping line 307663: expected 2 fields, saw 3
# Skipping line 307665: expected 2 fields, saw 7
# Skipping line 307669: expected 2 fields, saw 4
# Skipping line 307670: expected 2 fields, saw 5
# Skipping line 307672: expected 2 fields, saw 3
# Skipping line 307673: expected 2 fields, saw 8
# Skipping line 307674: expected 2 fields, saw 3
# Skipping line 307675: expected 2 fields, saw 5
# Skipping line 307677: expected 2 fields, saw 3
# Skipping line 307678: expected 2 fields, saw 3
# Skipping line 307681: expected 2 fields, saw 4
# Skipping line 307683: expected 2 fields, saw 4
# Skipping line 307684: expected 2 fields, saw 5
# Skipping line 307693: expected 2 fields, saw 3
# Skipping line 307694: expected 2 fields, saw 8
# Skipping line 307695: expected 2 fields, saw 3
# Skipping line 307698: expected 2 fields, saw 5
# Skipping line 307702: expected 2 fields, saw 4
# Skipping line 307704: expected 2 fields, saw 3
# Skipping line 307706: expected 2 fields, saw 5
# Skipping line 307709: expected 2 fields, saw 3
# Skipping line 307711: expected 2 fields, saw 5
# Skipping line 307712: expected 2 fields, saw 5
# Skipping line 307713: expected 2 fields, saw 4
# Skipping line 307714: expected 2 fields, saw 3
# Skipping line 307715: expected 2 fields, saw 3
# Skipping line 307716: expected 2 fields, saw 4
# Skipping line 307722: expected 2 fields, saw 5
# Skipping line 307726: expected 2 fields, saw 5
# Skipping line 307729: expected 2 fields, saw 5
# Skipping line 307730: expected 2 fields, saw 5
# Skipping line 307733: expected 2 fields, saw 5
# Skipping line 307734: expected 2 fields, saw 3
# Skipping line 307735: expected 2 fields, saw 3
# Skipping line 307736: expected 2 fields, saw 5
# Skipping line 307737: expected 2 fields, saw 5
# Skipping line 307739: expected 2 fields, saw 3
# Skipping line 307741: expected 2 fields, saw 3
# Skipping line 307742: expected 2 fields, saw 3
# Skipping line 307743: expected 2 fields, saw 3
# Skipping line 307746: expected 2 fields, saw 3
# Skipping line 307747: expected 2 fields, saw 3
# Skipping line 307748: expected 2 fields, saw 8
# Skipping line 307749: expected 2 fields, saw 3
# Skipping line 307750: expected 2 fields, saw 9
# Skipping line 307752: expected 2 fields, saw 5
# Skipping line 307755: expected 2 fields, saw 8
# Skipping line 307756: expected 2 fields, saw 3
# Skipping line 307757: expected 2 fields, saw 3
# Skipping line 307759: expected 2 fields, saw 5
# Skipping line 307764: expected 2 fields, saw 5
# Skipping line 307768: expected 2 fields, saw 3
# Skipping line 307769: expected 2 fields, saw 3
# Skipping line 307770: expected 2 fields, saw 5
# Skipping line 307773: expected 2 fields, saw 4
# Skipping line 307774: expected 2 fields, saw 4
# Skipping line 307775: expected 2 fields, saw 3
# Skipping line 307779: expected 2 fields, saw 3
# Skipping line 307781: expected 2 fields, saw 5
# Skipping line 307783: expected 2 fields, saw 3
# Skipping line 307786: expected 2 fields, saw 3
# Skipping line 307788: expected 2 fields, saw 5
# Skipping line 307789: expected 2 fields, saw 5
# Skipping line 307790: expected 2 fields, saw 5
# Skipping line 307792: expected 2 fields, saw 3
# Skipping line 307795: expected 2 fields, saw 3
# Skipping line 307796: expected 2 fields, saw 8
# Skipping line 307797: expected 2 fields, saw 3
# Skipping line 307799: expected 2 fields, saw 5
# Skipping line 307800: expected 2 fields, saw 4
# Skipping line 307802: expected 2 fields, saw 3
# Skipping line 307804: expected 2 fields, saw 4
# Skipping line 307806: expected 2 fields, saw 3
# Skipping line 307808: expected 2 fields, saw 5
# Skipping line 307809: expected 2 fields, saw 3
# Skipping line 307810: expected 2 fields, saw 3
# Skipping line 307811: expected 2 fields, saw 3
# Skipping line 307812: expected 2 fields, saw 3
# Skipping line 307813: expected 2 fields, saw 4
# Skipping line 307814: expected 2 fields, saw 4
# Skipping line 307815: expected 2 fields, saw 3
# Skipping line 307816: expected 2 fields, saw 3
# Skipping line 307817: expected 2 fields, saw 5
# Skipping line 307822: expected 2 fields, saw 4
# Skipping line 307823: expected 2 fields, saw 5
# Skipping line 307827: expected 2 fields, saw 5
# Skipping line 307829: expected 2 fields, saw 5
# Skipping line 307833: expected 2 fields, saw 3
# Skipping line 307834: expected 2 fields, saw 3
# Skipping line 307835: expected 2 fields, saw 3
# Skipping line 307836: expected 2 fields, saw 5
# Skipping line 307838: expected 2 fields, saw 6
# Skipping line 307840: expected 2 fields, saw 3
# Skipping line 307841: expected 2 fields, saw 5
# Skipping line 307844: expected 2 fields, saw 8
# Skipping line 307847: expected 2 fields, saw 3
# Skipping line 307849: expected 2 fields, saw 3
# Skipping line 307851: expected 2 fields, saw 3
# Skipping line 307852: expected 2 fields, saw 3
# Skipping line 307853: expected 2 fields, saw 3
# Skipping line 307860: expected 2 fields, saw 9
# Skipping line 307861: expected 2 fields, saw 3
# Skipping line 307864: expected 2 fields, saw 4
# Skipping line 307866: expected 2 fields, saw 5
# Skipping line 307869: expected 2 fields, saw 4
# Skipping line 307870: expected 2 fields, saw 5
# Skipping line 307871: expected 2 fields, saw 5
# Skipping line 307872: expected 2 fields, saw 3
# Skipping line 307874: expected 2 fields, saw 3
# Skipping line 307877: expected 2 fields, saw 4
# Skipping line 307878: expected 2 fields, saw 4
# Skipping line 307879: expected 2 fields, saw 5
# Skipping line 307880: expected 2 fields, saw 4
# Skipping line 307882: expected 2 fields, saw 4
# Skipping line 307885: expected 2 fields, saw 3
# Skipping line 307886: expected 2 fields, saw 3
# Skipping line 307889: expected 2 fields, saw 3
# Skipping line 307891: expected 2 fields, saw 4
# Skipping line 307892: expected 2 fields, saw 3
# Skipping line 307893: expected 2 fields, saw 7
# Skipping line 307896: expected 2 fields, saw 3
# Skipping line 307899: expected 2 fields, saw 8
# Skipping line 307901: expected 2 fields, saw 7
# Skipping line 307903: expected 2 fields, saw 7
# Skipping line 307904: expected 2 fields, saw 3
# Skipping line 307906: expected 2 fields, saw 3
# Skipping line 307907: expected 2 fields, saw 3
# Skipping line 307908: expected 2 fields, saw 5
# Skipping line 307909: expected 2 fields, saw 5
# Skipping line 307912: expected 2 fields, saw 3
# Skipping line 307914: expected 2 fields, saw 5
# Skipping line 307915: expected 2 fields, saw 3
# Skipping line 307916: expected 2 fields, saw 3
# Skipping line 307918: expected 2 fields, saw 5
# Skipping line 307919: expected 2 fields, saw 5
# Skipping line 307920: expected 2 fields, saw 5
# Skipping line 307921: expected 2 fields, saw 5
# Skipping line 307923: expected 2 fields, saw 5
# Skipping line 307924: expected 2 fields, saw 8
# Skipping line 307925: expected 2 fields, saw 9
# Skipping line 307927: expected 2 fields, saw 9
# Skipping line 307932: expected 2 fields, saw 3
# Skipping line 307934: expected 2 fields, saw 3
# Skipping line 307935: expected 2 fields, saw 4
# Skipping line 307936: expected 2 fields, saw 3
# Skipping line 307937: expected 2 fields, saw 5
# Skipping line 307938: expected 2 fields, saw 4
# Skipping line 307940: expected 2 fields, saw 4
# Skipping line 307942: expected 2 fields, saw 3
# Skipping line 307943: expected 2 fields, saw 3
# Skipping line 307945: expected 2 fields, saw 3
# Skipping line 307946: expected 2 fields, saw 5
# Skipping line 307949: expected 2 fields, saw 5
# Skipping line 307950: expected 2 fields, saw 4
# Skipping line 307951: expected 2 fields, saw 3
# Skipping line 307957: expected 2 fields, saw 4
# Skipping line 307961: expected 2 fields, saw 5
# Skipping line 307962: expected 2 fields, saw 3
# Skipping line 307965: expected 2 fields, saw 4
# Skipping line 307967: expected 2 fields, saw 4
# Skipping line 307969: expected 2 fields, saw 3
# Skipping line 307970: expected 2 fields, saw 5
# Skipping line 307971: expected 2 fields, saw 3
# Skipping line 307972: expected 2 fields, saw 5
# Skipping line 307973: expected 2 fields, saw 5
# Skipping line 307974: expected 2 fields, saw 3
# Skipping line 307979: expected 2 fields, saw 5
# Skipping line 307981: expected 2 fields, saw 3
# Skipping line 307984: expected 2 fields, saw 3
# Skipping line 307985: expected 2 fields, saw 3
# Skipping line 307986: expected 2 fields, saw 5
# Skipping line 307992: expected 2 fields, saw 5
# Skipping line 307993: expected 2 fields, saw 5
# Skipping line 307999: expected 2 fields, saw 5
# Skipping line 308004: expected 2 fields, saw 3
# Skipping line 308005: expected 2 fields, saw 3
# Skipping line 308006: expected 2 fields, saw 3
# Skipping line 308007: expected 2 fields, saw 8
# Skipping line 308008: expected 2 fields, saw 5
# Skipping line 308010: expected 2 fields, saw 5
# Skipping line 308012: expected 2 fields, saw 4
# Skipping line 308014: expected 2 fields, saw 8
# Skipping line 308015: expected 2 fields, saw 8
# Skipping line 308016: expected 2 fields, saw 5
# Skipping line 308022: expected 2 fields, saw 5
# Skipping line 308023: expected 2 fields, saw 3
# Skipping line 308024: expected 2 fields, saw 4
# Skipping line 308027: expected 2 fields, saw 4
# Skipping line 308031: expected 2 fields, saw 7
# Skipping line 308035: expected 2 fields, saw 6
# Skipping line 308036: expected 2 fields, saw 5
# Skipping line 308037: expected 2 fields, saw 3
# Skipping line 308038: expected 2 fields, saw 3
# Skipping line 308040: expected 2 fields, saw 3
# Skipping line 308042: expected 2 fields, saw 4
# Skipping line 308044: expected 2 fields, saw 3
# Skipping line 308045: expected 2 fields, saw 5
# Skipping line 308046: expected 2 fields, saw 3
# Skipping line 308049: expected 2 fields, saw 3
# Skipping line 308052: expected 2 fields, saw 3
# Skipping line 308053: expected 2 fields, saw 3
# Skipping line 308054: expected 2 fields, saw 3
# Skipping line 308055: expected 2 fields, saw 3
# Skipping line 308059: expected 2 fields, saw 5
# Skipping line 308062: expected 2 fields, saw 4
# Skipping line 308063: expected 2 fields, saw 3
# Skipping line 308064: expected 2 fields, saw 9
# Skipping line 308066: expected 2 fields, saw 6
# Skipping line 308067: expected 2 fields, saw 5
# Skipping line 308069: expected 2 fields, saw 3
# Skipping line 308070: expected 2 fields, saw 3
# Skipping line 308072: expected 2 fields, saw 5
# Skipping line 308075: expected 2 fields, saw 3
# Skipping line 308077: expected 2 fields, saw 10
# Skipping line 308081: expected 2 fields, saw 3
# Skipping line 308082: expected 2 fields, saw 3
# Skipping line 308084: expected 2 fields, saw 5
# Skipping line 308086: expected 2 fields, saw 3
# Skipping line 308090: expected 2 fields, saw 3
# Skipping line 308091: expected 2 fields, saw 5
# Skipping line 308093: expected 2 fields, saw 5
# Skipping line 308096: expected 2 fields, saw 5
# Skipping line 308097: expected 2 fields, saw 3
# Skipping line 308100: expected 2 fields, saw 8
# Skipping line 308104: expected 2 fields, saw 3
# Skipping line 308105: expected 2 fields, saw 3
# Skipping line 308111: expected 2 fields, saw 5
# Skipping line 308113: expected 2 fields, saw 3
# Skipping line 308114: expected 2 fields, saw 3
# Skipping line 308115: expected 2 fields, saw 4
# Skipping line 308118: expected 2 fields, saw 3
# Skipping line 308121: expected 2 fields, saw 5
# Skipping line 308122: expected 2 fields, saw 3
# Skipping line 308123: expected 2 fields, saw 5
# Skipping line 308125: expected 2 fields, saw 3
# Skipping line 308127: expected 2 fields, saw 8
# Skipping line 308132: expected 2 fields, saw 4
# Skipping line 308133: expected 2 fields, saw 5
# Skipping line 308136: expected 2 fields, saw 3
# Skipping line 308137: expected 2 fields, saw 4
# Skipping line 308139: expected 2 fields, saw 3
# Skipping line 308141: expected 2 fields, saw 5
# Skipping line 308146: expected 2 fields, saw 8
# Skipping line 308147: expected 2 fields, saw 3
# Skipping line 308154: expected 2 fields, saw 5
# Skipping line 308155: expected 2 fields, saw 4
# Skipping line 308156: expected 2 fields, saw 7
# Skipping line 308160: expected 2 fields, saw 9
# Skipping line 308163: expected 2 fields, saw 4
# Skipping line 308171: expected 2 fields, saw 5
# Skipping line 308173: expected 2 fields, saw 3
# Skipping line 308175: expected 2 fields, saw 3
# Skipping line 308177: expected 2 fields, saw 3
# Skipping line 308178: expected 2 fields, saw 6
# Skipping line 308180: expected 2 fields, saw 3
# Skipping line 308182: expected 2 fields, saw 3
# Skipping line 308184: expected 2 fields, saw 5
# Skipping line 308186: expected 2 fields, saw 5
# Skipping line 308189: expected 2 fields, saw 5
# Skipping line 308194: expected 2 fields, saw 4
# Skipping line 308196: expected 2 fields, saw 6
# Skipping line 308199: expected 2 fields, saw 4
# Skipping line 308203: expected 2 fields, saw 3
# Skipping line 308210: expected 2 fields, saw 5
# Skipping line 308211: expected 2 fields, saw 5
# Skipping line 308215: expected 2 fields, saw 3
# Skipping line 308216: expected 2 fields, saw 5
# Skipping line 308217: expected 2 fields, saw 5
# Skipping line 308218: expected 2 fields, saw 4
# Skipping line 308220: expected 2 fields, saw 4
# Skipping line 308226: expected 2 fields, saw 5
# Skipping line 308230: expected 2 fields, saw 3
# Skipping line 308231: expected 2 fields, saw 5
# Skipping line 308233: expected 2 fields, saw 5
# Skipping line 308235: expected 2 fields, saw 3
# Skipping line 308236: expected 2 fields, saw 5
# Skipping line 308239: expected 2 fields, saw 7
# Skipping line 308241: expected 2 fields, saw 5
# Skipping line 308246: expected 2 fields, saw 3
# Skipping line 308247: expected 2 fields, saw 5
# Skipping line 308248: expected 2 fields, saw 5
# Skipping line 308249: expected 2 fields, saw 3
# Skipping line 308252: expected 2 fields, saw 3
# Skipping line 308255: expected 2 fields, saw 3
# Skipping line 308257: expected 2 fields, saw 6
# Skipping line 308260: expected 2 fields, saw 3
# Skipping line 308262: expected 2 fields, saw 8
# Skipping line 308263: expected 2 fields, saw 7
# Skipping line 308266: expected 2 fields, saw 3
# Skipping line 308268: expected 2 fields, saw 8
# Skipping line 308269: expected 2 fields, saw 3
# Skipping line 308270: expected 2 fields, saw 3
# Skipping line 308271: expected 2 fields, saw 3
# Skipping line 308272: expected 2 fields, saw 9
# Skipping line 308273: expected 2 fields, saw 5
# Skipping line 308274: expected 2 fields, saw 3
# Skipping line 308276: expected 2 fields, saw 3
# Skipping line 308278: expected 2 fields, saw 3
# Skipping line 308280: expected 2 fields, saw 9
# Skipping line 308282: expected 2 fields, saw 3
# Skipping line 308284: expected 2 fields, saw 3
# Skipping line 308287: expected 2 fields, saw 3
# Skipping line 308289: expected 2 fields, saw 3
# Skipping line 308290: expected 2 fields, saw 3
# Skipping line 308292: expected 2 fields, saw 7
# Skipping line 308293: expected 2 fields, saw 3
# Skipping line 308294: expected 2 fields, saw 3
# Skipping line 308296: expected 2 fields, saw 3
# Skipping line 308298: expected 2 fields, saw 4
# Skipping line 308299: expected 2 fields, saw 3
# Skipping line 308304: expected 2 fields, saw 3
# Skipping line 308305: expected 2 fields, saw 3
# Skipping line 308308: expected 2 fields, saw 4
# Skipping line 308310: expected 2 fields, saw 5
# Skipping line 308311: expected 2 fields, saw 3
# Skipping line 308312: expected 2 fields, saw 3
# Skipping line 308313: expected 2 fields, saw 5
# Skipping line 308315: expected 2 fields, saw 3
# Skipping line 308317: expected 2 fields, saw 4
# Skipping line 308318: expected 2 fields, saw 5
# Skipping line 308320: expected 2 fields, saw 3
# Skipping line 308322: expected 2 fields, saw 3
# Skipping line 308324: expected 2 fields, saw 3
# Skipping line 308327: expected 2 fields, saw 3
# Skipping line 308328: expected 2 fields, saw 3
# Skipping line 308330: expected 2 fields, saw 3
# Skipping line 308332: expected 2 fields, saw 5
# Skipping line 308334: expected 2 fields, saw 3
# Skipping line 308335: expected 2 fields, saw 9
# Skipping line 308345: expected 2 fields, saw 5
# Skipping line 308347: expected 2 fields, saw 3
# Skipping line 308351: expected 2 fields, saw 4
# Skipping line 308353: expected 2 fields, saw 5
# Skipping line 308354: expected 2 fields, saw 3
# Skipping line 308355: expected 2 fields, saw 4
# Skipping line 308356: expected 2 fields, saw 7
# Skipping line 308358: expected 2 fields, saw 5
# Skipping line 308360: expected 2 fields, saw 4
# Skipping line 308361: expected 2 fields, saw 4
# Skipping line 308362: expected 2 fields, saw 3
# Skipping line 308363: expected 2 fields, saw 3
# Skipping line 308365: expected 2 fields, saw 3
# Skipping line 308369: expected 2 fields, saw 6
# Skipping line 308370: expected 2 fields, saw 3
# Skipping line 308372: expected 2 fields, saw 3
# Skipping line 308374: expected 2 fields, saw 3
# Skipping line 308375: expected 2 fields, saw 5
# Skipping line 308378: expected 2 fields, saw 3
# Skipping line 308380: expected 2 fields, saw 4
# Skipping line 308385: expected 2 fields, saw 4
# Skipping line 308387: expected 2 fields, saw 4
# Skipping line 308392: expected 2 fields, saw 3
# Skipping line 308393: expected 2 fields, saw 3
# Skipping line 308394: expected 2 fields, saw 4
# Skipping line 308395: expected 2 fields, saw 3
# Skipping line 308399: expected 2 fields, saw 5
# Skipping line 308403: expected 2 fields, saw 5
# Skipping line 308406: expected 2 fields, saw 6
# Skipping line 308409: expected 2 fields, saw 5
# Skipping line 308418: expected 2 fields, saw 4
# Skipping line 308420: expected 2 fields, saw 7
# Skipping line 308426: expected 2 fields, saw 3
# Skipping line 308428: expected 2 fields, saw 5
# Skipping line 308429: expected 2 fields, saw 5
# Skipping line 308432: expected 2 fields, saw 3
# Skipping line 308433: expected 2 fields, saw 8
# Skipping line 308435: expected 2 fields, saw 3
# Skipping line 308436: expected 2 fields, saw 3
# Skipping line 308437: expected 2 fields, saw 3
# Skipping line 308440: expected 2 fields, saw 5
# Skipping line 308441: expected 2 fields, saw 3
# Skipping line 308443: expected 2 fields, saw 3
# Skipping line 308446: expected 2 fields, saw 6
# Skipping line 308447: expected 2 fields, saw 8
# Skipping line 308448: expected 2 fields, saw 4
# Skipping line 308451: expected 2 fields, saw 3
# Skipping line 308452: expected 2 fields, saw 5
# Skipping line 308456: expected 2 fields, saw 3
# Skipping line 308458: expected 2 fields, saw 3
# Skipping line 308461: expected 2 fields, saw 3
# Skipping line 308462: expected 2 fields, saw 4
# Skipping line 308465: expected 2 fields, saw 4
# Skipping line 308467: expected 2 fields, saw 5
# Skipping line 308469: expected 2 fields, saw 5
# Skipping line 308471: expected 2 fields, saw 3
# Skipping line 308478: expected 2 fields, saw 6
# Skipping line 308479: expected 2 fields, saw 5
# Skipping line 308482: expected 2 fields, saw 9
# Skipping line 308486: expected 2 fields, saw 3
# Skipping line 308490: expected 2 fields, saw 3
# Skipping line 308491: expected 2 fields, saw 5
# Skipping line 308492: expected 2 fields, saw 3
# Skipping line 308493: expected 2 fields, saw 3
# Skipping line 308494: expected 2 fields, saw 8
# Skipping line 308498: expected 2 fields, saw 4
# Skipping line 308499: expected 2 fields, saw 5
# Skipping line 308501: expected 2 fields, saw 3
# Skipping line 308502: expected 2 fields, saw 3
# Skipping line 308504: expected 2 fields, saw 4
# Skipping line 308506: expected 2 fields, saw 4
# Skipping line 308507: expected 2 fields, saw 5
# Skipping line 308508: expected 2 fields, saw 4
# Skipping line 308509: expected 2 fields, saw 3
# Skipping line 308511: expected 2 fields, saw 5
# Skipping line 308513: expected 2 fields, saw 3
# Skipping line 308515: expected 2 fields, saw 3
# Skipping line 308516: expected 2 fields, saw 7
# Skipping line 308518: expected 2 fields, saw 3
# Skipping line 308522: expected 2 fields, saw 5
# Skipping line 308523: expected 2 fields, saw 3
# Skipping line 308524: expected 2 fields, saw 3
# Skipping line 308526: expected 2 fields, saw 3
# Skipping line 308530: expected 2 fields, saw 3
# Skipping line 308531: expected 2 fields, saw 3
# Skipping line 308536: expected 2 fields, saw 3
# Skipping line 308538: expected 2 fields, saw 3
# Skipping line 308543: expected 2 fields, saw 6
# Skipping line 308544: expected 2 fields, saw 10
# Skipping line 308550: expected 2 fields, saw 3
# Skipping line 308551: expected 2 fields, saw 5
# Skipping line 308554: expected 2 fields, saw 3
# Skipping line 308556: expected 2 fields, saw 3
# Skipping line 308559: expected 2 fields, saw 3
# Skipping line 308560: expected 2 fields, saw 6
# Skipping line 308563: expected 2 fields, saw 3
# Skipping line 308564: expected 2 fields, saw 3
# Skipping line 308567: expected 2 fields, saw 5
# Skipping line 308570: expected 2 fields, saw 3
# Skipping line 308573: expected 2 fields, saw 5
# Skipping line 308574: expected 2 fields, saw 5
# Skipping line 308576: expected 2 fields, saw 3
# Skipping line 308578: expected 2 fields, saw 7
# Skipping line 308579: expected 2 fields, saw 5
# Skipping line 308580: expected 2 fields, saw 5
# Skipping line 308581: expected 2 fields, saw 3
# Skipping line 308582: expected 2 fields, saw 5
# Skipping line 308584: expected 2 fields, saw 4
# Skipping line 308592: expected 2 fields, saw 5
# Skipping line 308593: expected 2 fields, saw 5
# Skipping line 308595: expected 2 fields, saw 6
# Skipping line 308603: expected 2 fields, saw 3
# Skipping line 308606: expected 2 fields, saw 3
# Skipping line 308611: expected 2 fields, saw 4
# Skipping line 308616: expected 2 fields, saw 7
# Skipping line 308618: expected 2 fields, saw 3
# Skipping line 308619: expected 2 fields, saw 5
# Skipping line 308621: expected 2 fields, saw 3
# Skipping line 308623: expected 2 fields, saw 5
# Skipping line 308625: expected 2 fields, saw 4
# Skipping line 308627: expected 2 fields, saw 3
# Skipping line 308628: expected 2 fields, saw 3
# Skipping line 308631: expected 2 fields, saw 7
# Skipping line 308633: expected 2 fields, saw 3
# Skipping line 308635: expected 2 fields, saw 5
# Skipping line 308639: expected 2 fields, saw 3
# Skipping line 308640: expected 2 fields, saw 5
# Skipping line 308642: expected 2 fields, saw 5
# Skipping line 308644: expected 2 fields, saw 5
# Skipping line 308645: expected 2 fields, saw 3
# Skipping line 308646: expected 2 fields, saw 3
# Skipping line 308649: expected 2 fields, saw 5
# Skipping line 308650: expected 2 fields, saw 5
# Skipping line 308651: expected 2 fields, saw 3
# Skipping line 308657: expected 2 fields, saw 3
# Skipping line 308658: expected 2 fields, saw 5
# Skipping line 308660: expected 2 fields, saw 4
# Skipping line 308661: expected 2 fields, saw 4
# Skipping line 308665: expected 2 fields, saw 3
# Skipping line 308668: expected 2 fields, saw 3
# Skipping line 308673: expected 2 fields, saw 9
# Skipping line 308674: expected 2 fields, saw 3
# Skipping line 308678: expected 2 fields, saw 5
# Skipping line 308679: expected 2 fields, saw 3
# Skipping line 308682: expected 2 fields, saw 3
# Skipping line 308684: expected 2 fields, saw 3
# Skipping line 308685: expected 2 fields, saw 4
# Skipping line 308686: expected 2 fields, saw 3
# Skipping line 308688: expected 2 fields, saw 5
# Skipping line 308689: expected 2 fields, saw 4
# Skipping line 308691: expected 2 fields, saw 4
# Skipping line 308692: expected 2 fields, saw 3
# Skipping line 308693: expected 2 fields, saw 3
# Skipping line 308695: expected 2 fields, saw 3
# Skipping line 308696: expected 2 fields, saw 3
# Skipping line 308699: expected 2 fields, saw 4
# Skipping line 308703: expected 2 fields, saw 8
# Skipping line 308706: expected 2 fields, saw 3
# Skipping line 308707: expected 2 fields, saw 3
# Skipping line 308709: expected 2 fields, saw 4
# Skipping line 308710: expected 2 fields, saw 5
# Skipping line 308711: expected 2 fields, saw 3
# Skipping line 308714: expected 2 fields, saw 4
# Skipping line 308715: expected 2 fields, saw 5
# Skipping line 308716: expected 2 fields, saw 8
# Skipping line 308718: expected 2 fields, saw 5
# Skipping line 308719: expected 2 fields, saw 4
# Skipping line 308722: expected 2 fields, saw 5
# Skipping line 308724: expected 2 fields, saw 5
# Skipping line 308725: expected 2 fields, saw 4
# Skipping line 308728: expected 2 fields, saw 3
# Skipping line 308734: expected 2 fields, saw 3
# Skipping line 308738: expected 2 fields, saw 5
# Skipping line 308740: expected 2 fields, saw 5
# Skipping line 308749: expected 2 fields, saw 3
# Skipping line 308750: expected 2 fields, saw 4
# Skipping line 308751: expected 2 fields, saw 4
# Skipping line 308754: expected 2 fields, saw 3
# Skipping line 308755: expected 2 fields, saw 5
# Skipping line 308759: expected 2 fields, saw 3
# Skipping line 308760: expected 2 fields, saw 5
# Skipping line 308761: expected 2 fields, saw 4
# Skipping line 308765: expected 2 fields, saw 5
# Skipping line 308771: expected 2 fields, saw 5
# Skipping line 308772: expected 2 fields, saw 4
# ...
# Skipping line 317105: expected 2 fields, saw 9
# Skipping line 317106: expected 2 fields, saw 6
# Skipping line 317108: expected 2 fields, saw 5
# Skipping line 317110: expected 2 fields, saw 4
# Skipping line 317111: expected 2 fields, saw 3
# Skipping line 317112: expected 2 fields, saw 3
# Skipping line 317113: expected 2 fields, saw 3
# Skipping line 317115: expected 2 fields, saw 3
# Skipping line 317118: expected 2 fields, saw 3
# Skipping line 317122: expected 2 fields, saw 3
# Skipping line 317123: expected 2 fields, saw 3
# Skipping line 317126: expected 2 fields, saw 3
# Skipping line 317130: expected 2 fields, saw 3
# Skipping line 317131: expected 2 fields, saw 5
# Skipping line 317132: expected 2 fields, saw 4
# Skipping line 317133: expected 2 fields, saw 3
# Skipping line 317135: expected 2 fields, saw 3
# Skipping line 317136: expected 2 fields, saw 3
# Skipping line 317137: expected 2 fields, saw 3
# Skipping line 317139: expected 2 fields, saw 3
# Skipping line 317140: expected 2 fields, saw 5
# Skipping line 317141: expected 2 fields, saw 3
# Skipping line 317142: expected 2 fields, saw 5
# Skipping line 317145: expected 2 fields, saw 3
# Skipping line 317146: expected 2 fields, saw 3
# Skipping line 317148: expected 2 fields, saw 3
# Skipping line 317149: expected 2 fields, saw 5
# Skipping line 317150: expected 2 fields, saw 4
# Skipping line 317154: expected 2 fields, saw 7
# Skipping line 317156: expected 2 fields, saw 4
# Skipping line 317157: expected 2 fields, saw 3
# Skipping line 317158: expected 2 fields, saw 4
# Skipping line 317160: expected 2 fields, saw 3
# Skipping line 317165: expected 2 fields, saw 3
# Skipping line 317166: expected 2 fields, saw 4
# Skipping line 317167: expected 2 fields, saw 4
# Skipping line 317169: expected 2 fields, saw 3
# Skipping line 317170: expected 2 fields, saw 3
# Skipping line 317176: expected 2 fields, saw 5
# Skipping line 317179: expected 2 fields, saw 3
# Skipping line 317182: expected 2 fields, saw 5
# Skipping line 317183: expected 2 fields, saw 3
# Skipping line 317184: expected 2 fields, saw 5
# Skipping line 317186: expected 2 fields, saw 3
# Skipping line 317187: expected 2 fields, saw 3
# Skipping line 317188: expected 2 fields, saw 4
# Skipping line 317189: expected 2 fields, saw 4
# Skipping line 317191: expected 2 fields, saw 5
# Skipping line 317192: expected 2 fields, saw 3
# Skipping line 317194: expected 2 fields, saw 5
# Skipping line 317195: expected 2 fields, saw 5
# Skipping line 317201: expected 2 fields, saw 5
# Skipping line 317202: expected 2 fields, saw 5
# Skipping line 317205: expected 2 fields, saw 5
# Skipping line 317211: expected 2 fields, saw 5
# Skipping line 317212: expected 2 fields, saw 3
# Skipping line 317213: expected 2 fields, saw 5
# Skipping line 317216: expected 2 fields, saw 5
# Skipping line 317219: expected 2 fields, saw 4
# Skipping line 317220: expected 2 fields, saw 7
# Skipping line 317222: expected 2 fields, saw 6
# Skipping line 317225: expected 2 fields, saw 3
# Skipping line 317226: expected 2 fields, saw 3
# Skipping line 317227: expected 2 fields, saw 3
# Skipping line 317230: expected 2 fields, saw 3
# Skipping line 317232: expected 2 fields, saw 3
# Skipping line 317233: expected 2 fields, saw 10
# Skipping line 317235: expected 2 fields, saw 5
# Skipping line 317238: expected 2 fields, saw 6
# Skipping line 317239: expected 2 fields, saw 7
# Skipping line 317241: expected 2 fields, saw 7
# Skipping line 317248: expected 2 fields, saw 4
# Skipping line 317250: expected 2 fields, saw 3
# Skipping line 317251: expected 2 fields, saw 4
# Skipping line 317252: expected 2 fields, saw 7
# Skipping line 317254: expected 2 fields, saw 4
# Skipping line 317259: expected 2 fields, saw 3
# Skipping line 317261: expected 2 fields, saw 3
# Skipping line 317265: expected 2 fields, saw 5
# Skipping line 317269: expected 2 fields, saw 6
# Skipping line 317272: expected 2 fields, saw 3
# Skipping line 317274: expected 2 fields, saw 5
# Skipping line 317277: expected 2 fields, saw 4
# Skipping line 317278: expected 2 fields, saw 5
# Skipping line 317282: expected 2 fields, saw 3
# Skipping line 317287: expected 2 fields, saw 5
# Skipping line 317288: expected 2 fields, saw 4
# Skipping line 317290: expected 2 fields, saw 6
# Skipping line 317291: expected 2 fields, saw 3
# Skipping line 317297: expected 2 fields, saw 3
# Skipping line 317298: expected 2 fields, saw 7
# Skipping line 317300: expected 2 fields, saw 3
# Skipping line 317301: expected 2 fields, saw 7
# Skipping line 317302: expected 2 fields, saw 3
# Skipping line 317304: expected 2 fields, saw 3
# Skipping line 317309: expected 2 fields, saw 5
# Skipping line 317310: expected 2 fields, saw 3
# Skipping line 317312: expected 2 fields, saw 5
# Skipping line 317314: expected 2 fields, saw 3
# Skipping line 317318: expected 2 fields, saw 4
# Skipping line 317319: expected 2 fields, saw 5
# Skipping line 317320: expected 2 fields, saw 5
# Skipping line 317328: expected 2 fields, saw 5
# Skipping line 317329: expected 2 fields, saw 4
# Skipping line 317330: expected 2 fields, saw 4
# Skipping line 317334: expected 2 fields, saw 3
# Skipping line 317335: expected 2 fields, saw 3
# Skipping line 317336: expected 2 fields, saw 3
# Skipping line 317337: expected 2 fields, saw 4
# Skipping line 317341: expected 2 fields, saw 6
# Skipping line 317344: expected 2 fields, saw 5
# Skipping line 317350: expected 2 fields, saw 4
# Skipping line 317351: expected 2 fields, saw 5
# Skipping line 317355: expected 2 fields, saw 8
# Skipping line 317360: expected 2 fields, saw 5
# Skipping line 317363: expected 2 fields, saw 5
# Skipping line 317365: expected 2 fields, saw 3
# Skipping line 317366: expected 2 fields, saw 5
# Skipping line 317367: expected 2 fields, saw 3
# Skipping line 317375: expected 2 fields, saw 3
# Skipping line 317379: expected 2 fields, saw 4
# Skipping line 317383: expected 2 fields, saw 3
# Skipping line 317384: expected 2 fields, saw 5
# Skipping line 317386: expected 2 fields, saw 5
# Skipping line 317390: expected 2 fields, saw 5
# Skipping line 317392: expected 2 fields, saw 5
# Skipping line 317393: expected 2 fields, saw 3
# Skipping line 317398: expected 2 fields, saw 3
# Skipping line 317401: expected 2 fields, saw 3
# Skipping line 317405: expected 2 fields, saw 4
# Skipping line 317409: expected 2 fields, saw 6
# Skipping line 317411: expected 2 fields, saw 5
# Skipping line 317413: expected 2 fields, saw 5
# Skipping line 317414: expected 2 fields, saw 4
# Skipping line 317418: expected 2 fields, saw 8
# Skipping line 317420: expected 2 fields, saw 3
# Skipping line 317424: expected 2 fields, saw 3
# Skipping line 317432: expected 2 fields, saw 4
# Skipping line 317436: expected 2 fields, saw 3
# Skipping line 317437: expected 2 fields, saw 5
# Skipping line 317442: expected 2 fields, saw 3
# Skipping line 317444: expected 2 fields, saw 4
# Skipping line 317446: expected 2 fields, saw 3
# Skipping line 317447: expected 2 fields, saw 4
# Skipping line 317452: expected 2 fields, saw 5
# Skipping line 317455: expected 2 fields, saw 5
# Skipping line 317457: expected 2 fields, saw 3
# Skipping line 317463: expected 2 fields, saw 3
# Skipping line 317464: expected 2 fields, saw 3
# Skipping line 317465: expected 2 fields, saw 4
# Skipping line 317467: expected 2 fields, saw 5
# Skipping line 317468: expected 2 fields, saw 5
# Skipping line 317469: expected 2 fields, saw 5
# Skipping line 317470: expected 2 fields, saw 4
# Skipping line 317476: expected 2 fields, saw 5
# Skipping line 317479: expected 2 fields, saw 5
# Skipping line 317489: expected 2 fields, saw 3
# Skipping line 317494: expected 2 fields, saw 5
# Skipping line 317499: expected 2 fields, saw 5
# Skipping line 317507: expected 2 fields, saw 3
# Skipping line 317517: expected 2 fields, saw 5
# Skipping line 317522: expected 2 fields, saw 3
# Skipping line 317524: expected 2 fields, saw 4
# Skipping line 317525: expected 2 fields, saw 4
# Skipping line 317526: expected 2 fields, saw 5
# Skipping line 317527: expected 2 fields, saw 3
# Skipping line 317528: expected 2 fields, saw 3
# Skipping line 317529: expected 2 fields, saw 3
# Skipping line 317533: expected 2 fields, saw 3
# Skipping line 317536: expected 2 fields, saw 5
# Skipping line 317538: expected 2 fields, saw 5
# Skipping line 317540: expected 2 fields, saw 3
# Skipping line 317541: expected 2 fields, saw 5
# Skipping line 317542: expected 2 fields, saw 6
# Skipping line 317543: expected 2 fields, saw 6
# Skipping line 317544: expected 2 fields, saw 3
# Skipping line 317549: expected 2 fields, saw 3
# Skipping line 317554: expected 2 fields, saw 3
# Skipping line 317556: expected 2 fields, saw 4
# Skipping line 317557: expected 2 fields, saw 3
# Skipping line 317559: expected 2 fields, saw 4
# Skipping line 317562: expected 2 fields, saw 3
# Skipping line 317563: expected 2 fields, saw 3
# Skipping line 317567: expected 2 fields, saw 4
# Skipping line 317569: expected 2 fields, saw 3
# Skipping line 317571: expected 2 fields, saw 5
# Skipping line 317574: expected 2 fields, saw 8
# Skipping line 317585: expected 2 fields, saw 7
# Skipping line 317589: expected 2 fields, saw 4
# Skipping line 317590: expected 2 fields, saw 5
# Skipping line 317591: expected 2 fields, saw 3
# Skipping line 317593: expected 2 fields, saw 3
# Skipping line 317594: expected 2 fields, saw 5
# Skipping line 317595: expected 2 fields, saw 4
# Skipping line 317596: expected 2 fields, saw 3
# Skipping line 317600: expected 2 fields, saw 5
# Skipping line 317603: expected 2 fields, saw 5
# Skipping line 317605: expected 2 fields, saw 3
# Skipping line 317607: expected 2 fields, saw 3
# Skipping line 317608: expected 2 fields, saw 5
# Skipping line 317614: expected 2 fields, saw 3
# Skipping line 317620: expected 2 fields, saw 5
# Skipping line 317624: expected 2 fields, saw 3
# Skipping line 317629: expected 2 fields, saw 3
# Skipping line 317630: expected 2 fields, saw 3
# Skipping line 317635: expected 2 fields, saw 3
# Skipping line 317636: expected 2 fields, saw 8
# Skipping line 317637: expected 2 fields, saw 3
# Skipping line 317638: expected 2 fields, saw 5
# Skipping line 317639: expected 2 fields, saw 3
# Skipping line 317641: expected 2 fields, saw 5
# Skipping line 317643: expected 2 fields, saw 3
# Skipping line 317644: expected 2 fields, saw 3
# Skipping line 317646: expected 2 fields, saw 3
# Skipping line 317647: expected 2 fields, saw 4
# Skipping line 317648: expected 2 fields, saw 3
# Skipping line 317657: expected 2 fields, saw 5
# Skipping line 317660: expected 2 fields, saw 3
# Skipping line 317662: expected 2 fields, saw 3
# Skipping line 317667: expected 2 fields, saw 3
# Skipping line 317668: expected 2 fields, saw 3
# Skipping line 317670: expected 2 fields, saw 3
# Skipping line 317674: expected 2 fields, saw 3
# Skipping line 317676: expected 2 fields, saw 4
# Skipping line 317677: expected 2 fields, saw 3
# Skipping line 317682: expected 2 fields, saw 3
# Skipping line 317684: expected 2 fields, saw 4
# Skipping line 317687: expected 2 fields, saw 3
# Skipping line 317690: expected 2 fields, saw 5
# Skipping line 317694: expected 2 fields, saw 3
# Skipping line 317695: expected 2 fields, saw 3
# Skipping line 317702: expected 2 fields, saw 5
# Skipping line 317705: expected 2 fields, saw 4
# Skipping line 317708: expected 2 fields, saw 5
# Skipping line 317711: expected 2 fields, saw 5
# Skipping line 317712: expected 2 fields, saw 5
# Skipping line 317714: expected 2 fields, saw 5
# Skipping line 317716: expected 2 fields, saw 5
# Skipping line 317722: expected 2 fields, saw 3
# Skipping line 317726: expected 2 fields, saw 4
# Skipping line 317731: expected 2 fields, saw 7
# Skipping line 317732: expected 2 fields, saw 4
# Skipping line 317734: expected 2 fields, saw 5
# Skipping line 317736: expected 2 fields, saw 5
# Skipping line 317738: expected 2 fields, saw 5
# Skipping line 317739: expected 2 fields, saw 3
# Skipping line 317742: expected 2 fields, saw 3
# Skipping line 317744: expected 2 fields, saw 3
# Skipping line 317746: expected 2 fields, saw 3
# Skipping line 317749: expected 2 fields, saw 3
# Skipping line 317750: expected 2 fields, saw 3
# Skipping line 317752: expected 2 fields, saw 3
# Skipping line 317753: expected 2 fields, saw 7
# Skipping line 317761: expected 2 fields, saw 3
# Skipping line 317763: expected 2 fields, saw 3
# Skipping line 317767: expected 2 fields, saw 3
# Skipping line 317770: expected 2 fields, saw 7
# Skipping line 317771: expected 2 fields, saw 3
# Skipping line 317778: expected 2 fields, saw 3
# Skipping line 317779: expected 2 fields, saw 5
# Skipping line 317781: expected 2 fields, saw 5
# Skipping line 317783: expected 2 fields, saw 4
# Skipping line 317784: expected 2 fields, saw 3
# Skipping line 317785: expected 2 fields, saw 3
# Skipping line 317787: expected 2 fields, saw 3
# Skipping line 317793: expected 2 fields, saw 3
# Skipping line 317795: expected 2 fields, saw 3
# Skipping line 317797: expected 2 fields, saw 3
# Skipping line 317798: expected 2 fields, saw 4
# Skipping line 317799: expected 2 fields, saw 3
# Skipping line 317800: expected 2 fields, saw 5
# Skipping line 317810: expected 2 fields, saw 5
# Skipping line 317811: expected 2 fields, saw 3
# Skipping line 317813: expected 2 fields, saw 3
# Skipping line 317818: expected 2 fields, saw 3
# Skipping line 317822: expected 2 fields, saw 4
# Skipping line 317823: expected 2 fields, saw 5
# Skipping line 317830: expected 2 fields, saw 7
# Skipping line 317832: expected 2 fields, saw 3
# Skipping line 317833: expected 2 fields, saw 3
# Skipping line 317834: expected 2 fields, saw 5
# Skipping line 317836: expected 2 fields, saw 3
# Skipping line 317838: expected 2 fields, saw 3
# Skipping line 317841: expected 2 fields, saw 4
# Skipping line 317842: expected 2 fields, saw 5
# Skipping line 317843: expected 2 fields, saw 3
# Skipping line 317844: expected 2 fields, saw 6
# Skipping line 317846: expected 2 fields, saw 4
# Skipping line 317847: expected 2 fields, saw 3
#
#   df = pd.concat([pd.read_csv(arq, on_bad_lines='warn') for arq in arquivos])
#                                                    Gestor;Canal de Origem;Região;UF;Cidade;Sexo;Faixa Etária;Ano Abertura;Mês Abertura;Data Abertura;Data Resposta;Data Análise;Data Recusa;Data Finalização;Prazo Resposta;Prazo Analise Gestor;Tempo Resposta;Nome Fantasia;Segmento de Mercado;Área;Assunto;Grupo Problema;Problema;Como Comprou Contratou;Procurou Empresa;Respondida;Situação;Avaliação Reclamação;Nota do Consumidor;Análise da Recusa
# (Fundação de Proteção e Defesa do Consumidor;Pl...   dano físico ou mal estar decorrente da presta...
# (Secretaria Nacional do Consumidor;Plataforma W...                                                NaN
# (Programa Estadual de Proteção e Defesa do Cons...                                                NaN
# (Fundação de Proteção e Defesa do Consumidor;Pl...                                                NaN
# (Programa Estadual de Proteção e Defesa do Cons...                                                NaN

# %%
df.shape
# Out:
# (605392, 1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 605392 entries, ('Fundação de Proteção e Defesa do Consumidor;Plataforma Web;SE;SP;São Paulo;M;entre 41 a 50 anos;2025;8;15/08/2025;;04/09/2025;20/08/2025;2025-10-01;09/09/2025;15;;Netshoes;Comércio Eletrônico;Demais Produtos;Vestuário e Artigos de Uso Pessoal (roupa', ' calçados', ' jóias', ' bijuterias', ' malas', ' bolsas', ' etc);Saúde e Segurança;Risco') to Fundação de Proteção e Defesa do Consumidor;Plataforma Web;SE;SP;Cotia;M;entre 41 a 50 anos;2025;12;31/12/2025;31/12/2025;;;2025-12-31;15/01/2026;;0;Serasa Experian ;Bancos de Dados e Cadastros de Consumidores;Serviços Financeiros;Consulta / Monitoramento de CPF;Cobrança / Contestação;Negativação indevida - desconhece motivo e/ou fornecedor;Não comprei / contratei;N;S;Finalizada avaliada;Não Resolvida;1;
# Data columns (total 1 columns):
#  #   Column                                                                                                                                                                                                                                                                                                                                                                                                     Non-Null Count   Dtype
# ---  ------                                                                                                                                                                                                                                                                                                                                                                                                     --------------   -----
#  0   Gestor;Canal de Origem;Região;UF;Cidade;Sexo;Faixa Etária;Ano Abertura;Mês Abertura;Data Abertura;Data Resposta;Data Análise;Data Recusa;Data Finalização;Prazo Resposta;Prazo Analise Gestor;Tempo Resposta;Nome Fantasia;Segmento de Mercado;Área;Assunto;Grupo Problema;Problema;Como Comprou Contratou;Procurou Empresa;Respondida;Situação;Avaliação Reclamação;Nota do Consumidor;Análise da Recusa  170608 non-null  object
# dtypes: object(1)
# memory usage: 9.2+ MB

# %% [markdown]
# Nesta etapa, os dados mensais disponibilizados pelo Consumidor.gov.br
# foram carregados individualmente e posteriormente concatenados em um
# único DataFrame utilizando a biblioteca Pandas, com o objetivo de
# facilitar a análise exploratória dos dados.

# %%
df.columns
# Out:
# Index(['Gestor;Canal de Origem;Região;UF;Cidade;Sexo;Faixa Etária;Ano Abertura;Mês Abertura;Data Abertura;Data Resposta;Data Análise;Data Recusa;Data Finalização;Prazo Resposta;Prazo Analise Gestor;Tempo Resposta;Nome Fantasia;Segmento de Mercado;Área;Assunto;Grupo Problema;Problema;Como Comprou Contratou;Procurou Empresa;Respondida;Situação;Avaliação Reclamação;Nota do Consumidor;Análise da Recusa'], dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 605392 entries, ('Fundação de Proteção e Defesa do Consumidor;Plataforma Web;SE;SP;São Paulo;M;entre 41 a 50 anos;2025;8;15/08/2025;;04/09/2025;20/08/2025;2025-10-01;09/09/2025;15;;Netshoes;Comércio Eletrônico;Demais Produtos;Vestuário e Artigos de Uso Pessoal (roupa', ' calçados', ' jóias', ' bijuterias', ' malas', ' bolsas', ' etc);Saúde e Segurança;Risco') to Fundação de Proteção e Defesa do Consumidor;Plataforma Web;SE;SP;Cotia;M;entre 41 a 50 anos;2025;12;31/12/2025;31/12/2025;;;2025-12-31;15/01/2026;;0;Serasa Experian ;Bancos de Dados e Cadastros de Consumidores;Serviços Financeiros;Consulta / Monitoramento de CPF;Cobrança / Contestação;Negativação indevida - desconhece motivo e/ou fornecedor;Não comprei / contratei;N;S;Finalizada avaliada;Não Resolvida;1;
# Data columns (total 1 columns):
#  #   Column                                                                                                                                                                                                                                                                                                                                                                                                     Non-Null Count   Dtype
# ---  ------                                                                                                                                                                                                                                                                                                                                                                                                     --------------   -----
#  0   Gestor;Canal de Origem;Região;UF;Cidade;Sexo;Faixa Etária;Ano Abertura;Mês Abertura;Data Abertura;Data Resposta;Data Análise;Data Recusa;Data Finalização;Prazo Resposta;Prazo Analise Gestor;Tempo Resposta;Nome Fantasia;Segmento de Mercado;Área;Assunto;Grupo Problema;Problema;Como Comprou Contratou;Procurou Empresa;Respondida;Situação;Avaliação Reclamação;Nota do Consumidor;Análise da Recusa  170608 non-null  object
# dtypes: object(1)
# memory usage: 9.2+ MB

# %%
import pandas as pd

arquivos = [
    'basecompleta2025-12.csv',
    'basecompleta2025-10.csv',
    'basecompleta2025-11.csv'
]

df = pd.concat([
    pd.read_csv(arq, sep=';', encoding='latin-1')
    for arq in arquivos
])

df.head()
# Out:
#                                            ï»¿Gestor Canal de Origem RegiÃ£o  \
# 0  Programa Estadual de ProteÃ§Ã£o e Defesa do Co...  Plataforma Web      SE
# 1    FundaÃ§Ã£o de ProteÃ§Ã£o e Defesa do Consumidor  Plataforma Web      SE
# 2                  Secretaria Nacional do Consumidor  Plataforma Web      S
# 3  Programa Estadual de ProteÃ§Ã£o e Defesa do Co...  Plataforma Web      SE
# 4                  Secretaria Nacional do Consumidor  Plataforma Web      NE
#
#    UF                   Cidade Sexo       Faixa EtÃ¡ria  Ano Abertura  \
# 0  MG                  Barroso    M  entre 41 a 50 anos          2025
# 1  SP               SÃ£o Paulo    F  entre 41 a 50 anos          2025
# 2  RS   Sant'Ana do Livramento    O  entre 21 a 30 anos          2025
# 3  MG             Juiz de Fora    F     mais de 70 anos          2025
# 4  RN  S?o Gon?alo do Amarante    M  entre 41 a 50 anos          2025
#
#    MÃªs Abertura Data Abertura  ...  \
# 0             10    10/10/2025  ...
# 1             10    11/10/2025  ...
# 2             10    12/10/2025  ...
# 3             10    12/10/2025  ...
# 4             10    12/10/2025  ...
#
#                                              Assunto  \
# 0  CrÃ©dito Pessoal e Demais EmprÃ©stimos (exceto...
# 1  VestuÃ¡rio e Artigos de Uso Pessoal (roupa, ca...
# 2  Produtos relacionados a saÃºde, exceto medicam...
# 3  Conta corrente / SalÃ¡rio / PoupanÃ§a /Conta A...
# 4                         Telefonia MÃ³vel PrÃ©-paga
#
#               Grupo Problema  \
# 0  CobranÃ§a / ContestaÃ§Ã£o
# 1          Atendimento / SAC
# 2          Contrato / Oferta
# 3        VÃ­cio de Qualidade
# 4  CobranÃ§a / ContestaÃ§Ã£o
#
#                                             Problema  \
# 0  NegativaÃ§Ã£o indevida - desconhece motivo e/o...
# 1  MÃ¡ qualidade no atendimento (descortesia / de...
# 2  Recusa em cancelar compra/serviÃ§o no prazo de...
# 3                    Clonagem, fraude, furto e roubo
# 4  CobranÃ§a indevida / abusiva para alterar ou c...
#
#      Como Comprou Contratou Procurou Empresa  Respondida  \
# 0  NÃ£o comprei / contratei                N           N
# 1        Ganhei de presente                S           S
# 2                  Internet                S           N
# 3                  Telefone                S           S
# 4                  Telefone                S           S
#
#                  SituaÃ§Ã£o AvaliaÃ§Ã£o ReclamaÃ§Ã£o Nota do Consumidor  \
# 0  Finalizada nÃ£o avaliada            NÃ£o Avaliada                NaN
# 1  Finalizada nÃ£o avaliada            NÃ£o Avaliada                NaN
# 2  Finalizada nÃ£o avaliada            NÃ£o Avaliada                NaN
# 3  Finalizada nÃ£o avaliada            NÃ£o Avaliada                NaN
# 4  Finalizada nÃ£o avaliada            NÃ£o Avaliada                NaN
#
#   AnÃ¡lise da Recusa
# 0       Improcedente
# 1       Improcedente
# 2       Improcedente
# 3       Improcedente
# 4       Improcedente
#
# [5 rows x 30 columns]

# %% [markdown]
# Os arquivos CSV disponibilizados utilizam o ponto e vírgula como
# separador de campos. Por isso, foi necessário ajustar o parâmetro
# `sep=';'` no momento da leitura dos dados.

# %%
df = pd.concat([
    pd.read_csv(arq, sep=';', encoding='utf-8')
    for arq in arquivos
])

df.columns
# Out:
# Index(['Gestor', 'Canal de Origem', 'Região', 'UF', 'Cidade', 'Sexo',
#        'Faixa Etária', 'Ano Abertura', 'Mês Abertura', 'Data Abertura',
#        'Data Resposta', 'Data Análise', 'Data Recusa', 'Data Finalização',
#        'Prazo Resposta', 'Prazo Analise Gestor', 'Tempo Resposta',
#        'Nome Fantasia', 'Segmento de Mercado', 'Área', 'Assunto',
#        'Grupo Problema', 'Problema', 'Como Comprou Contratou',
#        'Procurou Empresa', 'Respondida', 'Situação', 'Avaliação Reclamação',
#        'Nota do Consumidor', 'Análise da Recusa'],
#       dtype='object')

# %% [markdown]
# Durante a leitura dos arquivos CSV, foi identificado um problema de
# codificação de caracteres (encoding), comum em bases de dados públicas.
# O problema foi corrigido ajustando o encoding correto na leitura dos
# arquivos, garantindo a correta exibição de caracteres acentuados.

# %%
colunas_usadas = [
    'Nome Fantasia',
    'Grupo Problema',
    'Data Abertura',
    'Situação'
]

df_reduzido = df[colunas_usadas]
df_reduzido.head()
# Out:
#              Nome Fantasia          Grupo Problema Data Abertura  \
# 0         Afinz (Sorocred)  Cobrança / Contestação    10/10/2025
# 1                     Puma       Atendimento / SAC    11/10/2025
# 2         Panvel Farmácias       Contrato / Oferta    12/10/2025
# 3  Caixa Econômica Federal      Vício de Qualidade    12/10/2025
# 4            Claro Celular  Cobrança / Contestação    12/10/2025
#
#                   Situação
# 0  Finalizada não avaliada
# 1  Finalizada não avaliada
# 2  Finalizada não avaliada
# 3  Finalizada não avaliada
# 4  Finalizada não avaliada

# %%
df_reduzido = df_reduzido.rename(columns={
    'Nome Fantasia': 'empresa',
    'Grupo Problema': 'problema',
    'Data Abertura': 'data',
    'Situação': 'status'
})

df_reduzido.head()
# Out:
#                    empresa                problema        data  \
# 0         Afinz (Sorocred)  Cobrança / Contestação  10/10/2025
# 1                     Puma       Atendimento / SAC  11/10/2025
# 2         Panvel Farmácias       Contrato / Oferta  12/10/2025
# 3  Caixa Econômica Federal      Vício de Qualidade  12/10/2025
# 4            Claro Celular  Cobrança / Contestação  12/10/2025
#
#                     status
# 0  Finalizada não avaliada
# 1  Finalizada não avaliada
# 2  Finalizada não avaliada
# 3  Finalizada não avaliada
# 4  Finalizada não avaliada

# %% [markdown]
# Após a carga correta,
# foram selecionadas apenas as colunas relevantes para o objetivo
# do projeto e os nomes foram padronizados.

# %%
df_reduzido.isnull().sum()
# Out:
# empresa     0
# problema    0
# data        0
# status      0
# dtype: int64

# %%
df_reduzido = df_reduzido.dropna()

# %% [markdown]
# As linhas com valores ausentes foram removidas para garantir consistência na análise.

# %%
df_reduzido['data'] = pd.to_datetime(
    df_reduzido['data'],
    errors='coerce',
    dayfirst=True
)

# %%
df_reduzido.isnull().sum()
# Out:
# empresa     0
# problema    0
# data        0
# status      0
# dtype: int64

# %%
df_reduzido = df_reduzido.dropna(subset=['data'])

# %% [markdown]
# Durante a conversão da coluna de datas, foram identificados formatos
# inconsistentes. Para tratar esse problema, foi utilizada a conversão
# com `errors='coerce'`, transformando valores inválidos em nulos, que
# foram posteriormente removidos para garantir a qualidade da análise.

# %%
reclamacoes_empresa = df_reduzido['empresa'].value_counts().head(10)
reclamacoes_empresa
# Out:
# empresa
# Nubank                     67661
# Serasa Experian            57681
# Banco do Brasil            30312
# Banco Santander            26891
# Banco Bradesco             26549
# Vivo - Telefônica          22322
# Caixa Econômica Federal    21774
# Banco Itaú Unibanco        17419
# Mercado Pago               13354
# Banco Pan                  13118
# Name: count, dtype: int64

# %% [markdown]
# Foi realizado o levantamento das empresas com maior número de reclamações,
# permitindo identificar aquelas que concentram a maior demanda de atendimento.

# %%
problemas_comuns = df_reduzido['problema'].value_counts().head(10)
problemas_comuns
# Out:
# problema
# Cobrança / Contestação          456710
# Contrato / Oferta                90984
# Atendimento / SAC                83070
# Vício de Qualidade               70212
# Dados Pessoais e Privacidade     64476
# Entrega do Produto               20730
# Informação                       13138
# Saúde e Segurança                 4043
# Name: count, dtype: int64

# %% [markdown]
# A análise dos tipos de problemas permite identificar as principais causas
# das reclamações registradas pelos consumidores.

# %%
status_reclamacoes = df_reduzido['status'].value_counts()
status_reclamacoes
# Out:
# status
# Finalizada não avaliada    507301
# Finalizada avaliada        203188
# Cancelada                   72039
# Encerrada                   20835
# Name: count, dtype: int64

# %% [markdown]
# A distribuição do status das reclamações mostra o percentual de casos
# resolvidos, em andamento ou não resolvidos.

# %%
reclamacoes_mes = df_reduzido.groupby(df_reduzido['data'].dt.to_period('M')).size()
reclamacoes_mes
# Out:
# data
# 2025-08      1790
# 2025-09    185007
# 2025-10    276204
# 2025-11    285994
# 2025-12     54368
# Freq: M, dtype: int64

# %% [markdown]
# A análise temporal permite observar a evolução do volume de reclamações
# ao longo dos meses analisados.

# %% [markdown]
# ## Relatório de Insights
#
#
# A análise exploratória revelou que poucas empresas concentram a maior
# parte das reclamações registradas no período analisado. Entre os
# principais problemas identificados estão questões relacionadas a
# cobrança e atendimento ao consumidor.
#
# Observou-se também que a maioria das reclamações possui status de
# resolvida, indicando que as empresas, em geral, buscam solucionar os
# problemas apresentados pelos consumidores.

# %%
df_reduzido.to_csv('/content/reclamacoes_tratadas.csv', index=False)
